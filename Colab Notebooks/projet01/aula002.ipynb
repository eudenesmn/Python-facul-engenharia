# %%
from re import template
#Atribuição mútipla
a, b = 1,2
print ('antes de troca')
print( f'o valor das variaveis : a={a}, b={b}') 
#primeira troca
temp = a
a=b
b = temp 
print('Primeira troca')
print( f"o valor das variaveis: a={a}, b={b}")

# segunda troca
a, b = b, a
print('Segunda troca')
print(f"o valor da variaveis: a={a}, b={b}")
# Out:
# antes de troca
# o valor das variaveis : a=1, b=2
# Primeira troca
# o valor das variaveis: a=2, b=1
# Segunda troca
# o valor da variaveis: a=1, b=2

# %% [markdown]
# # Nova seção
